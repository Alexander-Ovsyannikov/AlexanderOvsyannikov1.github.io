# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexander-Ovsyannikov/AlexanderOvsyannikov1.github.io/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_%D0%93%D1%80%D0%B0%D0%B4%D0%B8%D0%B5%D0%BD%D1%82%D0%BD%D1%8B%D0%B9_%D1%81%D0%BF%D1%83%D1%81%D0%BA_%D0%BD%D0%B0_%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D1%8F%D1%85_%D1%81_%D0%BE%D0%B4%D0%BD%D0%BE%D0%B9_%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D0%BE%D0%B9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Моделирование шарика

# %% [markdown]
# Во всех следующих задачах мы будем моделировать движение шарика (он ведь действительно скатывается вниз если мы его положим на какую-либо горку?)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Если мы рассмотри пример, который смотрели на уроке. А именно градиентный спуск на примере функции y = x^2

# %% [markdown]
# То увидим, что график данной функции чем-то напоминает ущелье. А точку, из которой мы стартуем и последующие её движения к минимуму параболы с помощью алгоритма градиентного спуска как раз и будут моделировать движение шарика.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Итак, подведем итог.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# P.S в примере из нашего последнего урока длину шага я обозначаю буквой ЭТА ( η‎ ), а на картинке выше длина шага обозначена буквой h.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Пример градиентного спуска на простой функции

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## №1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##№ 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##№ 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##№ 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)
